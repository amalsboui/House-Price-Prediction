# %%
import pandas as pd

df_tayara = pd.read_csv("data/raw/tayara.csv")
df_mubawab = pd.read_csv("data/raw/mubawab.csv")
df_immobilier = pd.read_csv("data/raw/immobilier.csv")

# %%
cities_mubawab = df_mubawab.iloc[:, -1].str.strip()
unique_cities_mubawab = sorted(cities_mubawab.unique())

cities_tayara = df_tayara.iloc[:, -1].str.strip()
unique_cities_tayara = sorted(cities_tayara.unique())

cities_immobilier = df_immobilier.iloc[:, -1].str.strip()
unique_cities_immobilier = sorted(
    df_immobilier.iloc[:, -1]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
)

print(unique_cities_mubawab)
print(unique_cities_tayara)
print(unique_cities_immobilier)
# Out:
# ['Aghir', 'Ajim', 'Akouda', 'Al-Qayrawan', 'Ariana', 'Aïn Draham', 'Barraket Essahel', 'Bekalta', 'Ben Arous', 'Beni Khalled', 'Beni Khiar', 'Bir Bouregba', 'Bizerte', 'Bizerte Nord', 'Bizerte Sud', 'Bou Arada', 'Bou Argoub', 'Bou Salem', 'Bouficha', 'Boumhel Bassatine', 'Béja', 'Carthage', 'Chebba', 'Cité De La Plage 1', 'Cité El Khadra', 'Cité El Menzah', 'Cité Ennarjes 1', 'Cité Ennouzha', 'Cité Ezzouhour 2', 'Cité Ezzouhour 3', 'Cité Hached', 'Cité Jaouhara', 'Cité Presidentielle', 'Cité Taieb Mhiri', 'Dar Châabane', 'Djerba', 'Douar Hicher', 'Douz', 'El Ain', 'El Alia', 'El Aouina', 'El Hamma', 'El Haouaria', 'El Hrairia', 'El Kabaria', 'El Ksar', 'El Maamoura', 'El Menzah', 'El Mida', 'El Mourouj', 'El Omrane', 'El Omrane Superieur', 'El Ouardia', 'Enfidha', 'Essouassi', 'Ettadhamen', 'Ettahrir', 'Ezzahra', 'Fouchana', 'Gabès', 'Gabès Sud', 'Gafsa', 'Gafsa Sud', 'Ghar El Melh', 'Grombalia', 'Hammam Chatt', 'Hammam El Ghezaz', 'Hammam Ghezèze', 'Hammam Lif', 'Hammam Sousse', 'Hammam Sousse Ghrabi', 'Hammamet', 'Hergla', 'Houmt Souk', 'Jedaida', 'Jemmal', 'Jendouba', 'Kairouan', 'Kairouan Nord', 'Kairouan Sud', 'Kalaat Landalous', 'Kalâa Kebira', 'Kalâa Sghira', 'Kasserine', 'Kasserine Nord', 'Kasserine Sud', 'Kerkennah', 'Khezama Est', 'Khezama Ouest', 'Korba', 'Ksar Hellal', 'Ksibet El-Médiouni', 'Ksour Essef', 'Kélibia', 'La Goulette', 'La Manouba', 'La Marsa', 'La Medina', 'La Soukra', 'Le Bardo', 'Le Kef', 'Le Kram', "M'Saken", 'Mahdia', 'Mahrès', 'Medjez El Bab', 'Menzel Bourguiba', 'Menzel Bouzelfa', 'Menzel Chaker', 'Menzel Jemil', 'Menzel Temime', 'Metline', 'Mezraya', 'Midoun', 'Midoun Zone Touristique', 'Mnihla', 'Mohamadia', 'Moknine', 'Monastir', 'Mornag', 'Mornaguia', 'Mégrine', 'Nabeul', 'Nouvelle Medina', 'Oued Ellil', 'Rades', 'Raf Raf', 'Raoued', 'Ras Jebel', 'Rejiche', 'Sahline', 'Sahloul', 'Sakiet Eddaier', 'Sakiet Ezzit', 'Salakta', 'Sayada', 'Sers', 'Sfax', 'Sfax Ouest', 'Sfax Sud', 'Sidi Abdelhamid', 'Sidi Bou Ali Sousse', 'Sidi Hassine', 'Sidi Thabet', 'Soliman', 'Somâa', 'Sousse', 'Sousse Corniche', 'Sousse Jaouhara', 'Sousse Riadh', 'Tabarka', 'Takelsa', 'Tantana', 'Tazarka', 'Tebourba', 'Tezdaine', 'Thyna', 'Tinja', 'Tozeur', 'Tunis', 'Téboulba', 'Utique', 'Zaghouan', 'Zarzis', 'Zarzouna']
# ['Ariana', 'Ben Arous', 'Benarous', 'Bizerte', 'Bja', 'Gabs', 'Gafsa', 'Jendouba', 'Kairouan', 'Kasserine', 'La Manouba', 'Lamanouba', 'Le Kef', 'Mahdia', 'Mdenine', 'Monastir', 'Nabeul', 'Sfax', 'Sidi Bouzid', 'Siliana', 'Sousse', 'Tozeur', 'Tunis', 'Zaghouan']
# ['Ariana', 'Ben Aro...', 'Ben Arous', 'Bizerte', 'El Omrane Superieur...', 'Kairouan', 'Mahdia', 'Nabeul', 'Sfax', 'Sousse', 'Tozeur', 'Tunis']

# %% [markdown]
# ### Data Inspection

# %%
df_mubawab.info()
df_mubawab.head()

df_tayara.info()
df_tayara.head()

df_immobilier.info()
df_immobilier.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6587 entries, 0 to 6586
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chambres          6587 non-null   int64
#  1   prix              6587 non-null   float64
#  2   source            6587 non-null   object
#  3   surface           6587 non-null   float64
#  4   titre             6587 non-null   object
#  5   type_bien         6587 non-null   object
#  6   type_transaction  6587 non-null   object
#  7   ville             6587 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 411.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1921 entries, 0 to 1920
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chambres          1921 non-null   int64
#  1   prix              1921 non-null   float64
#  2   source            1921 non-null   object
#  3   surface           1921 non-null   float64
#  4   titre             1921 non-null   object
#  5   type_bien         1921 non-null   object
#  6   type_transaction  1921 non-null   object
#  7   ville             1921 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 120.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chambres          726 non-null    int64
#  1   prix              726 non-null    float64
#  2   source            726 non-null    object
#  3   surface           726 non-null    float64
#  4   titre             726 non-null    object
#  5   type_bien         726 non-null    object
#  6   type_transaction  726 non-null    object
#  7   ville             681 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 45.5+ KB
#    chambres    prix      source  surface  \
# 0         2  1600.0  immobilier     80.0
# 1         2  1600.0  immobilier    140.0
# 2         2   900.0  immobilier    100.0
# 3         2   800.0  immobilier     80.0
# 4         4   275.0  immobilier    122.0
#
#                                             titre type_bien type_transaction  \
# 0                            Au coeur de la marsa    Appart         À Vendre
# 1             Appartement rayen à lannée hammamet    Appart         À Vendre
# 2                   Bureau s2 à lafayette, tunis.    Appart         À Vendre
# 3  Superbes appartements s2 neufs à gremda km 7,5    Appart         À Vendre
# 4                À vendre appartement s3 la marsa    Appart         À Vendre
#
#     ville
# 0   Tunis
# 1  Nabeul
# 2   Tunis
# 3    Sfax
# 4   Tunis

# %% [markdown]
# ###  Merge

# %%
import pandas as pd

df_all = pd.concat(
    [df_mubawab, df_tayara, df_immobilier],
    ignore_index=True
)

print(df_all.shape)
# Out:
# (9234, 8)

# %% [markdown]
# ### Normalize City Names

# %%
import re
import unidecode

def normalize_city(city):
    if not isinstance(city, str):
        return None
    city = city.strip().lower()
    city = unidecode.unidecode(city)
    city = re.sub(r"\s+", " ", city)
    return city

df_all["city_raw"] = df_all["ville"]
df_all["city_norm"] = df_all["city_raw"].apply(normalize_city)

# %% [markdown]
# ### City to Government mapping

# %%
CITY_TO_GOV = {
    # TUNIS
    "tunis": "Tunis",
    "la marsa": "Tunis",
    "carthage": "Tunis",
    "le bardo": "Tunis",
    "le kram": "Tunis",
    "la goulette": "Tunis",
    "el omrane": "Tunis",
    "el omrane superieur": "Tunis",
    "el kabaria": "Tunis",
    "el hrairia": "Tunis",
    "sidi hassine": "Tunis",

    # ARIANA
    "ariana": "Ariana",
    "raoued": "Ariana",
    "sidi thabet": "Ariana",
    "el menzah": "Ariana",
    "ennasr": "Ariana",

    # BEN AROUS
    "ben arous": "Ben Arous",
    "benarous": "Ben Arous",
    "rades": "Ben Arous",
    "ezzahra": "Ben Arous",
    "boumhel bassatine": "Ben Arous",
    "hammam chatt": "Ben Arous",
    "hammam lif": "Ben Arous",

    # MANOUBA
    "la manouba": "Manouba",
    "lamanouba": "Manouba",
    "douar hicher": "Manouba",

    # NABEUL
    "nabeul": "Nabeul",
    "hammamet": "Nabeul",
    "hammamet nord": "Nabeul",
    "korba": "Nabeul",
    "kelibia": "Nabeul",
    "takelsa": "Nabeul",
    "soliman": "Nabeul",
    "dar chaabane": "Nabeul",

    # SOUSSE
    "sousse": "Sousse",
    "sahloul": "Sousse",
    "khezama est": "Sousse",
    "khezama ouest": "Sousse",
    "jaouhara": "Sousse",
    "tantana": "Sousse",
    "hammam sousse": "Sousse",

    # SFAX
    "sfax": "Sfax",
    "sfax sud": "Sfax",
    "sfax ouest": "Sfax",

    # MONASTIR
    "monastir": "Monastir",
    "jemmal": "Monastir",
    "ksar hellal": "Monastir",

    # MAHDIA
    "mahdia": "Mahdia",
    "chebba": "Mahdia",

    # GABES
    "gabes": "Gabes",
    "gabs": "Gabes",

    # MEDNINE
    "medenine": "Mednine",
    "mdenine": "Mednine",
    "djerba": "Mednine",
    "houmt souk": "Mednine",
    "midoun": "Mednine",

    # KAIROUAN
    "kairouan": "Kairouan",

    # KASSERINE
    "kasserine": "Kasserine",

    # GAFSA
    "gafsa": "Gafsa",

    # TOZEUR
    "tozeur": "Tozeur",

    # ZAGHOUAN
    "zaghouan": "Zaghouan",
}

# %%
df_all["governorate"] = df_all["city_norm"].map(CITY_TO_GOV)

# %% [markdown]
# ### Drop ligns with empty column values

# %%
before = df_all.shape[0]
df_all = df_all.dropna(subset=["governorate", "surface", "prix", "chambres"])
after = df_all.shape[0]

print(f"Dropped {before - after} rows")
# Out:
# Dropped 1894 rows

# %%
df_all["governorate"].value_counts()
# Out:
# governorate
# Tunis        2779
# Nabeul       1556
# Ariana       1169
# Sousse        789
# Ben Arous     369
# Mednine       231
# Manouba       109
# Monastir      100
# Sfax           95
# Mahdia         84
# Kairouan       39
# Zaghouan        6
# Gafsa           4
# Gabes           4
# Kasserine       3
# Tozeur          3
# Name: count, dtype: int64

# %% [markdown]
# ### Dropping columns we don't need

# %%
#drop type_transaction column as they are all a vendre
df_all = df_all.drop(columns=["type_transaction"])

# %%
#drop city_raw column
df_all = df_all.drop(columns=["city_raw"])

# %%
# drop source column
df_all = df_all.drop(columns=["source"])

# %% [markdown]
# ### Renaming and saving final csv

# %%
df_clean = df_all.rename(columns={
    "prix": "price",
    "surface": "surface",
    "chambres": "rooms",
    "type_bien": "property_type",
})

df_clean = df_clean[
    [
        "price",
        "surface",
        "rooms",
        "governorate",
        "property_type",
    ]
]
df_clean.info()
df_clean.to_csv("data/clean/clean_housing_tunisia.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7340 entries, 0 to 9233
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          7340 non-null   float64
#  1   surface        7340 non-null   float64
#  2   rooms          7340 non-null   int64
#  3   governorate    7340 non-null   object
#  4   property_type  7340 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 344.1+ KB
